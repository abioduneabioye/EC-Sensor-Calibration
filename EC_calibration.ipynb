# %%
# !rm -rf /content/EC-Sensor-Calibration

# %%
# --- CLEAN SETUP ---

# Clone repo (NO TOKEN NEEDED)
# !git clone https://github.com/abioduneabioye/EC-Sensor-Calibration.git

# Move into repo
# %cd EC-Sensor-Calibration

# Verify structure
# !ls
# Out:
# Cloning into 'EC-Sensor-Calibration'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 49 (delta 9), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 195.00 KiB | 6.29 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/EC-Sensor-Calibration
# data  docs  README.md  requirements.txt  results  scripts

# %%
from google.colab import userdata
TOKEN = userdata.get("GITHUB_TOKEN")

# !git remote set-url origin https://{TOKEN}@github.com/abioduneabioye/EC-Sensor-Calibration.git

# %%
# Create the file
with open("requirements.txt", "w") as f:
    f.write("""pandas
numpy
matplotlib
scikit-learn
""")

# %%
# !git add requirements.txt
# !git commit -m "Add requirements.txt"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !pip install -r requirements.txt

# %%
# %cd /content/EC-Sensor-Calibration

# %cd /content/EC-Sensor-Calibration
# !git pull
# Out:
# /content/EC-Sensor-Calibration
# /content/EC-Sensor-Calibration
# Already up to date.

# %%
# !python scripts/calibrate_ec_sensor.py
# !python scripts/plot_results.py
# Out:
# Calibration Equation:
# EC = 0.9716 * Sensor + -13.4226
#
# Model Performance:
# R²   = 1.0000
# RMSE = 14.9357
# MAE  = 12.5587
#
# Calibration complete. Results saved to results/calibration_summary.csv
# Plots saved to results/figures/

# %%
# !git config --global user.name "Abiodun Emmanuel Abioye"
# !git config --global user.email "emmanuel.abioye@reedleycollege.edu"

# %%
# !ls results/figures
# Out:
# calibration_curve.png  ec_vs_concentration_log.png  error_plot.png

# %%
# !git add results/figures/*.png results/calibration_summary.csv
# !git commit -m "Add calibration results and plots"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !cp /content/EC_calibration.ipynb /content/EC-Sensor-Calibration/
# Out:
# cp: cannot stat '/content/EC_calibration.ipynb': No such file or directory
